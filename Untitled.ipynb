# %%
with open("/home/joe/bic_etl/cdos/lobbyist/data_source/Sub-Contractor_fixed.tsv") as fin:
    nlines=0
    for line in fin:
        nlines+=1
        print(line)
        spl = line.split("\t")
        for nn,val in enumerate(spl):
            print(nn,val)
        for c in line:
            print(c,ord(c))
        print("\n---------------------------------------------------\n")
        if nlines > 2:
            break
# Out:
# lobbyistLastName	lobbyistFirstName	lobbyistAddress1 lobbyistAddress2	lobbyistCity	lobbyistState	lobbyistZip primaryLobbyistID	annualLobbyistRegistrationID	subcontractorSource	subcontractorAddressLine1	subcontractorAddressLine2	subcontractorCity	subcontractorState	subcontractorZip	incomeAmountReceived	amountPaidToSubcontractor	incomeReceiptDate	subcontractorLastName	subcontractorFirstName	reportMonth	fiscalYear	reportDueDate
#
# 0 lobbyistLastName
# 1 lobbyistFirstName
# 2 lobbyistAddress1 lobbyistAddress2
# 3 lobbyistCity
# 4 lobbyistState
# 5 lobbyistZip primaryLobbyistID
# 6 annualLobbyistRegistrationID
# 7 subcontractorSource
# 8 subcontractorAddressLine1
# 9 subcontractorAddressLine2
# 10 subcontractorCity
# 11 subcontractorState
# 12 subcontractorZip
# 13 incomeAmountReceived
# 14 amountPaidToSubcontractor
# 15 incomeReceiptDate
# 16 subcontractorLastName
# 17 subcontractorFirstName
# 18 reportMonth
# 19 fiscalYear
# 20 reportDueDate
#
# l 108
# o 111
# b 98
# b 98
# y 121
# ...
